# %%
import midi
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy
# %matplotlib inline

# %%
class MidiTokenizer():
    def __init__(self, filepath):
        self.mid = midi.read_midifile(filepath)
        self.format = self.mid.format
        self.tick_relative = self.mid.tick_relative
        self.data = {i: [] for i in range(17)}
        
        if self.format == 0:
            self.parse_track([mid], self.tick_relative)
        elif self.format == 1:
            for track in self.mid:
                self.parse_track(track, self.tick_relative)
                
        for i in self.data.keys():
            self.data[i] = pd.DataFrame(self.data[i], columns=['start', 'duration', 'pitch', 'velocity'])
                            
    def parse_track(self, track, tick_relative=True):
        tick = 0
        pitch_data = {}
        
        for event in track:
            if type(event) != midi.NoteOnEvent and type(event) != midi.NoteOffEvent:
                continue

            tick = (tick + event.tick) if tick_relative else event.tick
            
            if event.velocity != 0:
                datum = [tick, None, event.pitch, event.velocity]
                self.data[event.channel].append(datum)
                try:
                    if pitch_data[event.pitch][-1][1] == None:
                        pitch_data[event.pitch][-1][1] = tick
                        
                    pitch_data[event.pitch].append(datum)
                except KeyError:
                    pitch_data[event.pitch] = [datum]
            else:
                pitch_data[event.pitch][-1][1] = tick - self.data[event.channel][-1][0]

# %%
mt = MidiTokenizer('data/no_quarter/NoQuarter.mid')
mt.data
# Out:
# {0:      start  duration  pitch  velocity
#  0        0        60     68       100
#  1       60        30     71       100
#  2       90       120     71       100
#  3      210        30     73       100
#  4      240        60     73       100
#  5      300        30     75       100
#  6      330       150     75       100
#  7      480        30     71       100
#  8      510        60     71       100
#  9      570        30     71       100
#  10     600        60     71       100
#  11     660        90     73       100
#  12     750        60     66       100
#  13     810        30     68       100
#  14     840       150     68       100
#  15     990        30     66        72
#  16    1020        30     68        72
#  17    1050        30     66        72
#  18    1080        60     64        72
#  19    1140        90     61        72
#  20    1230        30     68       100
#  21    1260        60     68       100
#  22    1320        60     71       100
# ...

# %%
mt.mid[14]
# Out:
# midi.Track(\
#   [midi.PortEvent(tick=0, data=[0]),
#    midi.TrackNameEvent(tick=0, text='Echo Fuzz Guitar', data=[69, 99, 104, 111, 32, 70, 117, 122, 122, 32, 71, 117, 105, 116, 97, 114]),
#    midi.ProgramChangeEvent(tick=0, channel=13, data=[81]),
#    midi.ControlChangeEvent(tick=0, channel=13, data=[7, 60]),
#    midi.ControlChangeEvent(tick=0, channel=13, data=[10, 99]),
#    midi.ControlChangeEvent(tick=58, channel=13, data=[93, 122]),
#    midi.ControlChangeEvent(tick=6, channel=13, data=[91, 121]),
#    midi.ControlChangeEvent(tick=1, channel=13, data=[91, 127]),
#    midi.ControlChangeEvent(tick=32567, channel=13, data=[7, 66]),
#    midi.ControlChangeEvent(tick=24, channel=13, data=[7, 66]),
#    midi.NoteOnEvent(tick=122, channel=13, data=[51, 57]),
#    midi.NoteOnEvent(tick=24, channel=13, data=[51, 57]),
#    midi.NoteOnEvent(tick=6, channel=13, data=[51, 0]),
#    midi.NoteOnEvent(tick=0, channel=13, data=[52, 57]),
# ...

# %%
mid = midi.read_midifile('data/no_quarter/NoQuarter.mid')
instrument_tracks = mid[1:16]

# %%
piano = instrument_tracks[1]

# %%
data = []
i, j = 0, 0
k = -1
tick = 0

while i < len(piano):
    event = piano[i]
    if type(event) == midi.NoteOnEvent:
        tick = tick + event.tick
        pitch, velocity = event.data
        
        if velocity != 0:
            data.append([tick, None, pitch, velocity])
            k += 1
            
            j = i + 1
            while j < len(piano):
                if type(piano[j]) == midi.NoteOnEvent:
                    data[k][1] = data[k][0] + piano[j].tick
                    break
                j += 1
    
    i += 1

# %%
minPitch, maxPitch = min(data, key=lambda x:x[2])[2], max(data, key=lambda x:x[2])[2]
minVelocity, maxVelocity = min(data, key=lambda x:x[3])[3], max(data, key=lambda x:x[3])[3]

# %%
for datum in data:
    space = np.linspace(datum[0], datum[1])
    plt.plot(space, [datum[2]]*len(space), linewidth=(datum[3])/(maxVelocity)*5)

# %%
data
# Out:
# [[132, 222, 68, 48],
#  [252, 342, 71, 49],
#  [372, 432, 73, 49],
#  [462, 612, 75, 49],
#  [642, 672, 71, 50],
#  [672, 732, 68, 50],
#  [732, 882, 70, 50],
#  [1122, 1182, 71, 51],
#  [1212, 1272, 71, 51],
#  [1272, 1332, 73, 52],
#  [1422, 1632, 68, 52],
#  [2052, 2142, 68, 54],
#  [2172, 2262, 71, 55],
#  [2292, 2352, 73, 56],
#  [2382, 2532, 75, 56],
#  [2562, 2562, 68, 56],
#  [2562, 2652, 71, 56],
#  [2652, 2712, 68, 56],
#  [3042, 3132, 71, 58],
#  [3132, 3192, 71, 58],
#  [3192, 3282, 73, 58],
#  [3342, 3552, 68, 59],
#  [4002, 4062, 68, 61],
#  [4092, 4182, 71, 61],
#  [4212, 4302, 73, 62],
#  [4332, 4482, 75, 62],
#  [4932, 4962, 75, 70],
#  [4962, 5052, 75, 70],
#  [5052, 5112, 75, 70],
#  [5112, 5172, 76, 70],
#  [5172, 5232, 76, 70],
#  [5232, 5292, 78, 70],
#  [5292, 5292, 68, 70],
#  [5292, 5442, 80, 70],
#  [5922, 5922, 80, 70],
#  [5922, 6012, 68, 70],
#  [6012, 6012, 68, 70],
#  [6012, 6072, 80, 70],
#  [6072, 6072, 83, 70],
#  [6072, 6132, 71, 70],
# ...

# %%
mid2[1]
# Out:
# midi.Track(\
#   [midi.PortEvent(tick=0, data=[0]),
#    midi.SequencerSpecificEvent(tick=0, data=[0, 0, 0, 106, 0, 4, 1]),
#    midi.TrackNameEvent(tick=0, text='Pad1', data=[80, 97, 100, 49]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[17]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[7, 65]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[67, 98]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 98]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[72, 119]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 119]),
#    midi.NoteOnEvent(tick=357, channel=0, data=[67, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[72, 0]),
#    midi.NoteOnEvent(tick=114, channel=0, data=[77, 107]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 107]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 90]),
# ...
